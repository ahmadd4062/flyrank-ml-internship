# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmadd4062/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# # Refresh / Content Opportunity Scoring
#
# I chose the **Refresh / Content Opportunity Scoring** lane because it focuses on helping content teams prioritize which pages should be reviewed first. Instead of trying to automate content decisions, the goal is to build a decision-support system that ranks pages based on observable search and engagement signals. This lane aligns well with the starter dataset and provides a practical machine learning problem where the output supports real content review actions.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# ## Research Question
#
# ### Decision
#
# Which content pages should be reviewed first for refresh or improvement?
#
# ### Action
#
# The ranked output helps content managers or SEO teams decide which pages to review before investing time and resources in updating them.
#
# ### Cost of a Wrong Recommendation
#
# If important pages are ranked too low, valuable opportunities may be missed, leading to continued traffic decline. If low-value pages are ranked too high, reviewers may spend time on pages that provide little benefit. Therefore, the ranking should support human decision-making rather than replace it.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# !git clone https://github.com/ahmadd4062/flyrank-ml-internship.git

import pandas as pd

df = pd.read_csv("/content/flyrank-ml-internship/data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))

df.head()

print("Trend Direction Distribution:")
print(df["trend_direction"].value_counts())

print("\nAverage 90-Day Impressions:")
print(df["impressions_90d"].mean())

print("\nAverage 90-Day Sessions:")
print(df["sessions_90d"].mean())
# Out:
# fatal: destination path 'flyrank-ml-internship' already exists and is not an empty directory.
# Rows: 30000
# Columns: 44
# Trend Direction Distribution:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
#
# Average 90-Day Impressions:
# 5200.3663
#
# Average 90-Day Sessions:
# 37.066633333333336

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# ## What I Can Claim
#
# This project will identify observed relationships between content performance signals and pages that may deserve review. The resulting rankings are intended to support content decisions by providing evidence-based recommendations.
#
# ## What I Cannot Claim
#
# This project cannot prove that refreshing a page will increase traffic or improve rankings. It also cannot predict Google's ranking algorithm or establish causal relationships. All findings should be interpreted as observational and decision-support evidence rather than guaranteed outcomes.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [yes] Every section above is filled — markdown thinking AND the code that backs it
# - [yes] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [yes] No client names, URLs, or private queries anywhere
# - [yes] My claims use careful words: observed, measured, directional, decision-support
# - [yes] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
